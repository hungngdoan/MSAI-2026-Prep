# %% [markdown]
# # Ch 08: PyTorch Paper Replicating - Sample
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Follow along with learnpytorch.io. Read, understand, and run each cell.
#
# **Topics:** Replicate a machine learning research paper in PyTorch. Read, understand, and implement a published deep learning architecture from scratch.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
