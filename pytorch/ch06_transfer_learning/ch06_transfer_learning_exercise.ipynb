# %% [markdown]
# # Ch 06: Transfer Learning - Exercise
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Type each code cell line by line from memory to build muscle memory.
#
# **Topics:** torchvision.models (EfficientNet_B0). Freeze base layers. Replace classifier head. Feature extraction: only train new head. Compare vs training from scratch.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
