# %% [markdown]
# # Ch 07: PyTorch Experiment Tracking - Sample
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Follow along with learnpytorch.io. Read, understand, and run each cell.
#
# **Topics:** Track and compare model experiments. TensorBoard and other tools for monitoring training runs, loss curves, and model performance across experiments.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
