# %% [markdown]
# # Ch 01: PyTorch Workflow - Data Prep & Model Building - Exercise
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Type each code cell line by line from memory to build muscle memory.
#
# **Topics:** Create synthetic linear data. Train/test split. Build nn.Module subclass. Loss fn (L1Loss, MSELoss) and optimizer (SGD). Training loop: forward, loss, zero_grad, backward, step.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
