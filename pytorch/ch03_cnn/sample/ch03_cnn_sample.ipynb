# %% [markdown]
# # Ch 03: Computer Vision - CNNs - Sample
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Follow along with learnpytorch.io. Read, understand, and run each cell.
#
# **Topics:** FashionMNIST with torchvision. DataLoader with batching. Baseline: flatten + linear. CNNs: spatial structure, parameter sharing. TinyVGG architecture.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
