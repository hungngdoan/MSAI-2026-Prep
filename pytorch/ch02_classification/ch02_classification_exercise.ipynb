# %% [markdown]
# # Ch 02: Neural Network Classification - Exercise
#
# **Source:** [learnpytorch.io](https://www.learnpytorch.io/)
#
# **Goal:** Type each code cell line by line from memory to build muscle memory.
#
# **Topics:** Binary classification with circles dataset. BCEWithLogitsLoss. Sigmoid for predictions. Linear model fails on nonlinear data. Add nn.ReLU layers.

# %%
import torch
print(f"PyTorch version: {torch.__version__}")

# %% [markdown]
# ## Start here
#
# Add your code cells below.
